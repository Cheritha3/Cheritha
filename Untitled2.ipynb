# %% [markdown]
# <a href="https://colab.research.google.com/github/Cheritha3/Cheritha/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
X = np.array([[1], [2], [3], [4], [5]])
Y = np.array([1, 2, 2.5, 4, 5])

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X)

# %%
plt.scatter(X, Y, color='blue')  # Actual data points
plt.plot(X, Y_pred, color='red')  # Regression line
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
print("Intercept (β0):", model.intercept_)
print("Coefficient (β1):", model.coef_)
# Out:
# Intercept (β0): -0.10000000000000009
# Coefficient (β1): [1.]

# %%
X = np.random.rand(100, 1) * 100  # 100 random numbers between 0 and 100
Y = 2 * X + np.random.randn(100, 1) * 10  # Linear relation with some noise

# %%
plt.scatter(X, Y, color='blue')
plt.title("Generated Dataset of 100 Numbers")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X)

# %%
plt.scatter(X, Y, color='blue')  # Actual data points
plt.plot(X, Y_pred, color='red')  # Regression line
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
! https://raw.githubusercontent.com/kgsb24/rishi-college/refs/heads/main/datasets/diabetes.csv
# Out:
# /bin/bash: line 1: https://raw.githubusercontent.com/kgsb24/rishi-college/refs/heads/main/datasets/diabetes.csv: No such file or directory

# %%
import pandas as pf
df = pd.read_csv('https://raw.githubusercontent.com/kgsb24/rishi-college/main/datasets/diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x=df[{'Blood pressure'}]
y=df[{'Age'}]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-58faab8bb828> in <cell line: 1>()
# ----> 1 x=df[{'Blood pressure'}]
#       2 y=df[{'Age'}]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4061
#    4062     def __getitem__(self, key):
# -> 4063         check_dict_or_set_indexers(key)
#    4064         key = lib.item_from_zerodim(key)
#    4065         key = com.apply_if_callable(key, self)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in check_dict_or_set_indexers(key)
#    2772         and any(isinstance(x, set) for x in key)
#    2773     ):
# -> 2774         raise TypeError(
#    2775             "Passing a set as an indexer is not supported. Use a list instead."
#    2776         )
#
# TypeError: Passing a set as an indexer is not supported. Use a list instead.
